# %% [markdown]
# # TP3 — Algeria Economic Dataset Analysis
# # تحليل البيانات الاقتصادية الجزائرية
#
# **EN:** Use pandas to load, clean, and analyze the Algeria economic dataset.
#
# **AR:** استخدم مكتبة pandas لتحميل وتنظيف وتحليل مجموعة البيانات الاقتصادية الجزائرية.
#
# ---
# **Dataset / الملف:** `algeria_economic_combined.csv`
# **Grade / التقييم:** /20

# %%
# Import libraries / استيراد المكتبات
import pandas as pd
import numpy as np

# Display settings / إعدادات العرض
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

print("Libraries imported successfully / تم استيراد المكتبات بنجاح")

# %% [markdown]
# ---
# ## Exercise 1 — Load & Explore (4 pts)
# ## التمرين 1 — التحميل والاستكشاف

# %%
# Exercise 1: Load and explore the dataset
# التمرين 1: تحميل البيانات واستكشافها

# TODO 1a: Load the CSV file
# تحميل ملف CSV
df = None  # pd.read_csv('algeria_economic_combined.csv')

# TODO 1b: Display the shape (rows, columns)
# عرض الشكل (الصفوف، الأعمدة)
print("Shape / الشكل:", None)  # df.shape

# TODO 1c: Display column names
# عرض أسماء الأعمدة
print("\nColumns / الأعمدة:")
# print(df.columns.tolist())

# TODO 1d: Display first 10 rows
# عرض أول 10 صفوف
# df.head(10)

# %%
# TODO 1e: Display data types of each column
# عرض أنواع البيانات لكل عمود
# df.dtypes

# TODO 1f: Display basic info
# عرض المعلومات الأساسية
# df.info()

# %% [markdown]
# ---
# ## Exercise 2 — Missing Values (3 pts)
# ## التمرين 2 — القيم المفقودة

# %%
# Exercise 2: Handle missing values
# التمرين 2: معالجة القيم المفقودة

# TODO 2a: Count missing values per column
# حساب القيم المفقودة لكل عمود
print("Missing values / القيم المفقودة:")
# print(df.isnull().sum())

# TODO 2b: Calculate percentage of missing values per column
# حساب نسبة القيم المفقودة
# missing_pct = (df.isnull().sum() / len(df)) * 100
# print(missing_pct[missing_pct > 0])

# TODO 2c: Choose a strategy and apply it:
# اختر استراتيجية وطبّقها:
#   Option A: Drop rows with missing values / حذف الصفوف: df.dropna()
#   Option B: Fill with mean / تعويض بالمتوسط: df.fillna(df.mean())
#   Option C: Fill with forward fill / تعويض للأمام: df.fillna(method='ffill')

# df_clean = None  # TODO: apply your chosen strategy

# TODO 2d: Justify your choice in a comment / برّر اختيارك في تعليق
# Your justification / مبررك:
# ...

# %% [markdown]
# ---
# ## Exercise 3 — Key Economic Calculations (6 pts)
# ## التمرين 3 — الحسابات الاقتصادية الأساسية

# %%
# Exercise 3a: Average annual GDP growth
# التمرين 3أ: متوسط نمو الناتج المحلي السنوي

# TODO: Calculate the mean of the GDP_Growth_Percent column
# احسب متوسط عمود GDP_Growth_Percent
# Hint: df['GDP_Growth_Percent'].mean()

avg_gdp_growth = None  # TODO
print(f"Average GDP Growth / متوسط نمو الناتج المحلي: {avg_gdp_growth:.2f}%")

# %%
# Exercise 3b: Year with highest inflation
# التمرين 3ب: السنة ذات أعلى تضخم

# TODO: Find the year where Inflation_Percent is maximum
# اعثر على السنة حيث التضخم هو الأعلى
# Hint: df.loc[df['Inflation_Percent'].idxmax(), 'Year']

max_inflation_year = None   # TODO
max_inflation_value = None  # TODO: df['Inflation_Percent'].max()

print(f"Highest inflation year / سنة أعلى تضخم: {max_inflation_year}")
print(f"Inflation rate / معدل التضخم: {max_inflation_value:.2f}%")

# %%
# Exercise 3c: Correlation between GDP growth and unemployment
# التمرين 3ج: الارتباط بين نمو الناتج المحلي والبطالة

# TODO: Calculate Pearson correlation between GDP_Growth_Percent and Unemployment_Rate
# احسب ارتباط بيرسون بين نمو الناتج المحلي ومعدل البطالة
# Hint: df['GDP_Growth_Percent'].corr(df['Unemployment_Rate'])

correlation = None  # TODO
print(f"Correlation / الارتباط: {correlation:.4f}")

# TODO: Interpret the result
# فسّر النتيجة
# Hint:
#   > 0.7  -> Strong positive / ارتباط موجب قوي
#   0.3-0.7 -> Moderate positive / ارتباط موجب متوسط
#   -0.3 to 0.3 -> Weak / ارتباط ضعيف
#   < -0.3 -> Negative / ارتباط سالب
if correlation is not None:
    pass  # TODO: print interpretation

# %% [markdown]
# ---
# ## Exercise 4 — Descriptive Statistics Table (3 pts)
# ## التمرين 4 — جدول الإحصاء الوصفي

# %%
# Exercise 4: Full descriptive statistics
# التمرين 4: الإحصاءات الوصفية الكاملة

# TODO 4a: Show describe() for all numeric columns
# عرض describe() لجميع الأعمدة العددية
# df.describe().round(2)

# TODO 4b: Calculate and print for each numeric column:
# احسب واطبع لكل عمود عددي:
numeric_cols = ['GDP_Growth_Percent', 'Inflation_Percent', 'Unemployment_Rate']

print(f"{'Column':<25} {'Mean':>8} {'Std':>8} {'Min':>8} {'Max':>8}")
print("-" * 65)

for col in numeric_cols:
    # TODO: calculate mean, std, min, max for each column
    # احسب المتوسط والانحراف المعياري والحد الأدنى والأقصى
    mean = None  # df[col].mean()
    std  = None  # df[col].std()
    vmin = None  # df[col].min()
    vmax = None  # df[col].max()
    # print(f"{col:<25} {mean:>8.2f} {std:>8.2f} {vmin:>8.2f} {vmax:>8.2f}")

# %% [markdown]
# ---
# ## Exercise 5 — Economic Insights (4 pts)
# ## التمرين 5 — الاستنتاجات الاقتصادية
#
# **EN:** Write 3 economic insights from your analysis. Each insight = 1 code cell with a comment and a `print()` statement that supports the insight with a number.
#
# **AR:** اكتب 3 استنتاجات اقتصادية من تحليلك. كل استنتاج = خلية كود تحتوي تعليقاً وجملة `print()` تدعم الاستنتاج برقم.

# %%
# Insight 1 / الاستنتاج الأول
# TODO: Write your insight as a comment, then support it with a calculation
# اكتب استنتاجك كتعليق، ثم ادعمه بحساب
#
# Example / مثال:
# "Algeria experienced high inflation between 2021 and 2023 (above 9%)"
# "عانت الجزائر من تضخم مرتفع بين 2021 و2023 (فوق 9%)"

# Your insight:
print("Insight 1:")
# TODO: calculation that supports your insight

# %%
# Insight 2 / الاستنتاج الثاني
print("Insight 2:")
# TODO

# %%
# Insight 3 / الاستنتاج الثالث
print("Insight 3:")
# TODO

# %% [markdown]
# ---
# ## Self-Check / قائمة المراجعة
#
# - [ ] Dataset loaded and shape/columns displayed / البيانات محمّلة والشكل والأعمدة معروضة
# - [ ] Missing values handled with justification / القيم المفقودة معالجة مع تبرير
# - [ ] Average GDP growth calculated / متوسط نمو الناتج المحلي محسوب
# - [ ] Year of max inflation found / سنة أعلى تضخم محددة
# - [ ] Correlation calculated and interpreted / الارتباط محسوب ومفسّر
# - [ ] Describe() table shown / جدول describe() معروض
# - [ ] 3 original insights written / 3 استنتاجات أصلية مكتوبة
# - [ ] All cells run without errors / كل الخلايا تعمل بدون أخطاء
