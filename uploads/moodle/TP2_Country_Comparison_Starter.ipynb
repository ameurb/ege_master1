# %% [markdown]
# # TP2 — Country Comparison / مقارنة الدول
#
# **EN:** Use Python lists, dictionaries, loops, and conditions to compare North African economies.
#
# **AR:** استخدم القوائم والقواميس وحلقات التكرار والشروط لمقارنة اقتصادات دول شمال أفريقيا.
#
# ---
# **Grade / التقييم:** /20
# **Data file / ملف البيانات:** `world_bank_economic_indicators.csv` (available on EGE platform)

# %% [markdown]
# ## Quick Reference / مرجع سريع
#
# ```python
# # List / قائمة
# rates = [2.1, 2.5, 1.8]
# rates.append(3.0)        # add element / إضافة عنصر
# rates[0]                 # first element / أول عنصر
# len(rates)               # length / الطول
# sum(rates)               # sum / المجموع
# max(rates)               # maximum / الأكبر
# min(rates)               # minimum / الأصغر
# sorted(rates)            # sort / ترتيب
#
# # Dictionary / قاموس
# data = {"Algeria": 25100, "Morocco": 1260}
# data["Algeria"]          # access value / الوصول للقيمة
# data.keys()              # all keys / كل المفاتيح
# data.values()            # all values / كل القيم
# data.items()             # key-value pairs / أزواج
#
# # Loop / حلقة تكرار
# for country, gdp in data.items():
#     print(country, gdp)
#
# # Condition / شرط
# if gdp > 10000:
#     print("Large economy")
# elif gdp > 1000:
#     print("Medium economy")
# else:
#     print("Small economy")
# ```

# %% [markdown]
# ---
# ## Exercise 1 — Build the Dataset (3 pts)
# ## التمرين 1 — بناء مجموعة البيانات
#
# **EN:** Create a dictionary with GDP 2023 (billions DZD equivalent) for 5 North African countries.
#
# **AR:** أنشئ قاموساً يحتوي على الناتج المحلي لسنة 2023 لـ 5 دول من شمال أفريقيا.

# %%
# Exercise 1: Build the dataset
# التمرين 1: بناء مجموعة البيانات

# GDP in billions DZD (approximate 2023 values)
# الناتج المحلي الإجمالي بالمليار دينار جزائري (قيم تقريبية 2023)
gdp_data = {
    "Algeria / الجزائر":  None,   # TODO: 25100
    "Morocco / المغرب":   None,   # TODO: 13200
    "Tunisia / تونس":     None,   # TODO: 4800
    "Egypt / مصر":        None,   # TODO: 38000
    "Libya / ليبيا":      None,   # TODO: 8600
}

# Also create a dictionary for GDP growth rates (%)
# أنشئ أيضاً قاموساً لمعدلات نمو الناتج المحلي (%)
growth_data = {
    "Algeria / الجزائر":  None,   # TODO: 2.4
    "Morocco / المغرب":   None,   # TODO: 3.1
    "Tunisia / تونس":     None,   # TODO: 0.4
    "Egypt / مصر":        None,   # TODO: 4.2
    "Libya / ليبيا":      None,   # TODO: 1.5
}

print("Dataset created! / تم إنشاء مجموعة البيانات")
print(f"Number of countries / عدد الدول: {len(gdp_data)}")

# %% [markdown]
# ---
# ## Exercise 2 — Find Richest and Poorest (4 pts)
# ## التمرين 2 — إيجاد الأغنى والأفقر
#
# **EN:** Use a loop to find the country with the highest and lowest GDP.
#
# **AR:** استخدم حلقة تكرارية لإيجاد الدولة ذات أعلى وأدنى ناتج محلي.

# %%
# Exercise 2: Find richest and poorest country
# التمرين 2: إيجاد الأغنى والأفقر

# Initialize tracking variables / تهيئة متغيرات التتبع
richest_country = None
richest_gdp = 0
poorest_country = None
poorest_gdp = float('inf')  # Start with infinity / ابدأ بالمالانهاية

# TODO: Loop through gdp_data.items()
# For each (country, gdp):
#   - if gdp > richest_gdp: update richest_country and richest_gdp
#   - if gdp < poorest_gdp: update poorest_country and poorest_gdp

for country, gdp in gdp_data.items():
    pass  # TODO: replace pass with your logic

print(f"Richest / الأغنى: {richest_country} — {richest_gdp:,} B DZD")
print(f"Poorest / الأفقر: {poorest_country} — {poorest_gdp:,} B DZD")

# %% [markdown]
# ---
# ## Exercise 3 — Regional Average & Classification (4 pts)
# ## التمرين 3 — المتوسط الإقليمي والتصنيف
#
# **EN:** Calculate the regional average GDP, then classify each country as above or below average.
#
# **AR:** احسب متوسط الناتج المحلي الإقليمي، ثم صنّف كل دولة بأنها فوق أو دون المتوسط.

# %%
# Exercise 3: Average and classification
# التمرين 3: المتوسط والتصنيف

# Step 1: Calculate average GDP
# الخطوة 1: احسب متوسط الناتج المحلي
gdp_values = list(gdp_data.values())
average_gdp = None  # TODO: sum(gdp_values) / len(gdp_values)

print(f"Regional Average GDP / متوسط الناتج الإقليمي: {average_gdp:,.1f} B DZD")
print()

# Step 2: Classify each country
# الخطوة 2: صنّف كل دولة
print("Classification / التصنيف:")
print("-" * 50)

above_average = []  # countries above average
below_average = []  # countries below average

for country, gdp in gdp_data.items():
    # TODO: check if gdp >= average_gdp
    # If yes: append to above_average, print with "Above / فوق المتوسط"
    # If no: append to below_average, print with "Below / دون المتوسط"
    pass

print(f"\nAbove average / فوق المتوسط: {len(above_average)} countries")
print(f"Below average / دون المتوسط: {len(below_average)} countries")

# %% [markdown]
# ---
# ## Exercise 4 — Growth Classification (5 pts)
# ## التمرين 4 — تصنيف النمو الاقتصادي
#
# **EN:** For each country, classify its GDP growth rate using if/elif/else.
#
# **AR:** لكل دولة، صنّف معدل نمو ناتجها المحلي باستخدام if/elif/else.

# %%
# Exercise 4: Growth classification
# التمرين 4: تصنيف النمو

print("GDP Growth Classification / تصنيف معدلات النمو")
print("=" * 60)

for country, growth in growth_data.items():
    # TODO: classify growth using if/elif/else
    # > 5%  -> "Strong / قوي"
    # 2-5%  -> "Moderate / معتدل"
    # 0-2%  -> "Slow / بطيء"
    # < 0   -> "Recession / ركود"
    
    classification = None  # TODO: set based on growth value
    
    print(f"{country:<25} {growth:+.1f}%  →  {classification}")

print("=" * 60)

# BONUS: Find the fastest growing country
# مكافأة: اعثر على أسرع دولة نمواً

# %% [markdown]
# ---
# ## Exercise 5 — Inflation List Analysis (4 pts)
# ## التمرين 5 — تحليل قائمة التضخم
#
# **EN:** Analyze a list of Algeria's annual inflation rates (2015–2024).
#
# **AR:** حلّل قائمة معدلات التضخم السنوية للجزائر (2015–2024).

# %%
# Exercise 5: Inflation list analysis
# التمرين 5: تحليل قائمة التضخم

years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
inflation = [4.8, 6.4, 5.6, 4.3, 2.0, 2.4, 9.2, 9.3, 9.3, 5.5]  # percentage

# TODO 1: Print average inflation over the period
avg_inflation = None  # sum(...) / len(...)
print(f"Average inflation / متوسط التضخم: {avg_inflation:.2f}%")

# TODO 2: Find the year with highest inflation
# Hint: use inflation.index(max(inflation)) to get position, then years[position]
max_inflation = None
max_year = None
print(f"Highest inflation / أعلى تضخم: {max_inflation}% in {max_year}")

# TODO 3: Count years where inflation was above 5%
high_inflation_count = 0
for rate in inflation:
    pass  # TODO: increment counter if rate > 5
print(f"Years above 5% / سنوات التضخم فوق 5%: {high_inflation_count}")

# TODO 4 (BONUS): Print each year and its inflation rate
# sorted from highest to lowest inflation
# Use: sorted(zip(inflation, years), reverse=True)

# %% [markdown]
# ---
# ## Self-Check / قائمة المراجعة
#
# - [ ] Ex 1: Both dictionaries filled / كلا القاموسين مكتملان
# - [ ] Ex 2: Loop finds richest and poorest correctly / الحلقة تجد الأغنى والأفقر
# - [ ] Ex 3: Average calculated, countries classified / المتوسط محسوب والدول مصنّفة
# - [ ] Ex 4: All countries classified by growth / كل الدول مصنّفة حسب النمو
# - [ ] Ex 5: Average, max year, high-inflation count computed / المتوسط والسنة القصوى والعدد محسوبة
# - [ ] No errors when running all cells / لا أخطاء عند تشغيل كل الخلايا
