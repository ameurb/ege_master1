# %% [markdown]
# # TP1 — Economic Calculator / الآلة الحاسبة الاقتصادية
#
# **EN:** In this notebook you will apply Python fundamentals to solve real economic problems for Algeria.
#
# **AR:** في هذا الدفتر ستطبق أساسيات بايثون لحل مسائل اقتصادية حقيقية تخص الجزائر.
#
# ---
# **Learning Objectives / أهداف التعلم:**
# - EN: Use variables, data types, arithmetic operators, and f-strings
# - AR: استخدام المتغيرات وأنواع البيانات والعمليات الحسابية وf-strings
#
# **Grade / التقييم:** /20
# **Submit / التسليم:** Upload this `.ipynb` file on the EGE platform / ارفع هذا الملف على منصة EGE

# %% [markdown]
# ## Quick Reference / مرجع سريع
#
# | Operation | Symbol | Example |
# |-----------|--------|---------|
# | Addition / الجمع | `+` | `gdp + growth` |
# | Subtraction / الطرح | `-` | `gdp_new - gdp_old` |
# | Multiplication / الضرب | `*` | `principal * rate` |
# | Division / القسمة | `/` | `total_gdp / population` |
# | Power / القوة | `**` | `(1 + rate) ** years` |
# | Format float | `:.2f` | `f"{value:.2f}"` |
# | Format int with commas | `:,` | `f"{pop:,}"` |

# %% [markdown]
# ---
# ## Exercise 1 — GDP Growth Rate (4 pts)
# ## التمرين 1 — معدل نمو الناتج المحلي الإجمالي
#
# **Formula / الصيغة:**
# ```
# Growth Rate (%) = ((GDP_new - GDP_old) / GDP_old) × 100
# ```
# **Data / البيانات:** Algeria GDP 2023 = 24,500 billion DZD | GDP 2024 = 25,100 billion DZD

# %%
# Exercise 1: GDP Growth Rate
# التمرين 1: معدل نمو الناتج المحلي الإجمالي

# --- Step 1: Define your variables / الخطوة 1: عرّف متغيراتك ---
gdp_2023 = None   # TODO: replace None with 24500
gdp_2024 = None   # TODO: replace None with 25100

# --- Step 2: Calculate absolute change / الخطوة 2: احسب التغيير المطلق ---
change = None     # TODO: gdp_2024 - gdp_2023

# --- Step 3: Calculate growth rate / الخطوة 3: احسب معدل النمو ---
growth_rate = None  # TODO: apply the formula above

# --- Step 4: Print results / الخطوة 4: اطبع النتائج ---
# TODO: print GDP 2023, GDP 2024, and growth rate formatted to 2 decimal places
# مثال: print(f"GDP Growth Rate: {growth_rate:.2f}%")

# --- Step 5: Interpretation / الخطوة 5: التفسير ---
# TODO: print a message based on growth_rate:
#   > 5%  -> "Strong growth / نمو قوي"
#   2-5%  -> "Moderate growth / نمو معتدل"
#   0-2%  -> "Slow growth / نمو بطيء"
#   < 0   -> "Recession / ركود"

# %% [markdown]
# ---
# ## Exercise 2 — Inflation Rate (4 pts)
# ## التمرين 2 — معدل التضخم
#
# **Formula / الصيغة:**
# ```
# Inflation (%) = ((CPI_new - CPI_old) / CPI_old) × 100
# ```
# **Data / البيانات:** CPI 2023 = 108.5 | CPI 2024 = 111.2

# %%
# Exercise 2: Inflation Rate
# التمرين 2: معدل التضخم

cpi_2023 = None   # TODO: 108.5
cpi_2024 = None   # TODO: 111.2

# TODO: calculate inflation_rate using the formula
inflation_rate = None

# TODO: print the result formatted to 2 decimal places

# TODO: calculate and print the real-world impact:
# If a family spends 50,000 DZD/month in 2023,
# how much will the same basket cost in 2024?
basket_2023 = 50000
basket_2024 = None   # TODO: basket_2023 * (cpi_2024 / cpi_2023)
# print the extra monthly cost

# %% [markdown]
# ---
# ## Exercise 3 — GDP per Capita (4 pts)
# ## التمرين 3 — نصيب الفرد من الناتج المحلي
#
# **Formula / الصيغة:**
# ```
# GDP per Capita = Total GDP / Population
# ```
# **Data / البيانات:** GDP 2024 = 25,100 billion DZD | Population = 46,000,000

# %%
# Exercise 3: GDP per Capita
# التمرين 3: نصيب الفرد من الناتج المحلي الإجمالي

total_gdp_billions = None   # TODO: 25100 (in billions DZD)
population = None           # TODO: 46000000

# Convert GDP to DZD (multiply by 1,000,000,000)
total_gdp_dzd = None        # TODO: total_gdp_billions * 1_000_000_000

# Calculate GDP per capita
gdp_per_capita = None       # TODO: total_gdp_dzd / population

# TODO: print result with comma formatting
# Expected output: GDP per Capita: 545,652.17 DZD

# BONUS: Compare with Morocco (GDP=1,260B DZD, pop=37M) and Tunisia (GDP=430B DZD, pop=12M)
# Which country has the highest GDP per capita?

# %% [markdown]
# ---
# ## Exercise 4 — Compound Interest (4 pts)
# ## التمرين 4 — الفائدة المركبة
#
# **Formula / الصيغة:**
# ```
# A = P × (1 + r)^t
# ```
# P = principal, r = annual rate, t = years
# P = رأس المال، r = معدل الفائدة السنوي، t = عدد السنوات
#
# **Data / البيانات:** P = 100,000 DZD | r = 5% | t = 5 years

# %%
# Exercise 4: Compound Interest
# التمرين 4: الفائدة المركبة

principal = None    # TODO: 100000
rate = None         # TODO: 0.05  (5%)
years = None        # TODO: 5

# Calculate final amount
final_amount = None  # TODO: principal * (1 + rate) ** years

# Calculate total interest earned
interest_earned = None  # TODO: final_amount - principal

# TODO: print principal, final amount, interest earned — all formatted with commas and 2 decimals

# BONUS: Compare simple interest vs compound interest for the same data
# Simple Interest: I = P * r * t
simple_interest = None  # TODO
# print which gives more and by how much

# %% [markdown]
# ---
# ## Exercise 5 — Full Economic Report (4 pts)
# ## التمرين 5 — التقرير الاقتصادي الكامل
#
# **EN:** Combine all calculations above into one clean report printed to the console.
#
# **AR:** اجمع كل الحسابات أعلاه في تقرير واحد منظّم يُطبع على الشاشة.

# %%
# Exercise 5: Full Economic Report for Algeria 2024
# التمرين 5: التقرير الاقتصادي الكامل للجزائر 2024

# TODO: Copy your final values from exercises 1-4
# Then print a formatted report like this:
#
# ============================================
#   ALGERIA ECONOMIC REPORT 2024
#   التقرير الاقتصادي للجزائر 2024
# ============================================
# GDP Growth Rate:    X.XX%  → [interpretation]
# Inflation Rate:     X.XX%  → [interpretation]
# GDP per Capita:     XXX,XXX DZD
# Investment Return:  XXX,XXX.XX DZD (after 5 years at 5%)
# ============================================

print("=" * 50)
print("  ALGERIA ECONOMIC REPORT 2024")
print("  التقرير الاقتصادي للجزائر 2024")
print("=" * 50)
# TODO: fill in the rest

# %% [markdown]
# ---
# ## Self-Check Before Submitting / قائمة المراجعة قبل التسليم
#
# - [ ] All 5 exercises completed / كل التمارين الخمسة مكتملة
# - [ ] All `None` values replaced with real code / كل قيم `None` استُبدلت بكود حقيقي
# - [ ] Numbers formatted with `.2f` and `,` where appropriate / الأرقام منسّقة بشكل صحيح
# - [ ] Interpretation messages printed / رسائل التفسير مطبوعة
# - [ ] Notebook runs without errors (Restart & Run All) / الدفتر يعمل بدون أخطاء
# - [ ] File saved as `.ipynb` / الملف محفوظ بصيغة `.ipynb`
